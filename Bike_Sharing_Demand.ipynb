# %% [markdown]
# ## Import Libraries

# %%
import pickle ## Save the model object to disk file
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # Python plotting library
import seaborn as sns # More snazzy plotting library


from datetime import datetime # Typcasting date of type object ans splitting it
from sklearn.preprocessing import StandardScaler # Feature Scaling (Normalizaiton)
from sklearn.preprocessing import PolynomialFeatures # Train polynomial regression 
from sklearn.model_selection import train_test_split # Out of sample testing
from sklearn.linear_model import LinearRegression

# %%
# Read csv file and create a dataframe called fileData
fileData = pd.read_csv("train.csv")

# %%
fileData.head(100)
# Out:
#                datetime  season  holiday  workingday  weather  temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ..                  ...     ...      ...         ...      ...   ...     ...
# 95  2011-01-05 04:00:00       1        0           1        1  9.84  11.365
# 96  2011-01-05 05:00:00       1        0           1        1  9.02  11.365
# 97  2011-01-05 06:00:00       1        0           1        1  8.20   9.850
# 98  2011-01-05 07:00:00       1        0           1        1  7.38   9.090
# 99  2011-01-05 08:00:00       1        0           1        1  8.20   9.090
#
#     humidity  windspeed  casual  registered  count
# 0         81     0.0000       3          13     16
# 1         80     0.0000       8          32     40
# 2         80     0.0000       5          27     32
# 3         75     0.0000       3          10     13
# 4         75     0.0000       0           1      1
# ..       ...        ...     ...         ...    ...
# 95        48    15.0013       0           2      2
# 96        47    11.0014       0           3      3
# 97        47    15.0013       0          33     33
# 98        43    12.9980       1          87     88
# 99        40    19.9995       3         192    195
#
# [100 rows x 12 columns]

# %%
# Show data shape (# rows, # columns)
fileData.shape
# Out:
# (10886, 12)

# %%
# Show first 5 rows of the data
fileData.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
fileData.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
perc =[.25, .50, .75, .90]
desc = fileData.describe(percentiles = perc)
desc
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# 90%        4.000000      0.000000      1.000000      2.000000     30.34000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# 90%       34.090000     88.000000     23.999400     94.000000    354.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# 90%      452.000000
# max      977.000000

# %%
# Check for missing values
fileData.isna().any()
# Out:
# datetime      False
# season        False
# holiday       False
# workingday    False
# weather       False
# temp          False
# atemp         False
# humidity      False
# windspeed     False
# casual        False
# registered    False
# count         False
# dtype: bool

# %% [markdown]
# ##### Observing from above not having null values to handle(fill or drop)

# %%
#Detect distribution and skewness for features
fileData.hist(figsize=(15,15), 
              bins=100
             )
# Out:
# array([[<AxesSubplot:title={'center':'season'}>,
#         <AxesSubplot:title={'center':'holiday'}>,
#         <AxesSubplot:title={'center':'workingday'}>],
#        [<AxesSubplot:title={'center':'weather'}>,
#         <AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'atemp'}>],
#        [<AxesSubplot:title={'center':'humidity'}>,
#         <AxesSubplot:title={'center':'windspeed'}>,
#         <AxesSubplot:title={'center':'casual'}>],
#        [<AxesSubplot:title={'center':'registered'}>,
#         <AxesSubplot:title={'center':'count'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# observe null values & data types for features
fileData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# ##### Observe having a feature with object type, that is (datetime). That needs to be formatted by
# #####            1. convert datetime from object type to datetime
# #####            2. split datetime column to year, month, weekday and hour
# ##### Having categorical features represented in numbers, those are: Season, Holiday, Workingday, Weather

# %%
# convert datetime from object type to datetime
fileData.datetime = pd.to_datetime(fileData.datetime)

# %%
# split datetime column to year,month,weekday and hour 
fileData['year'] = fileData['datetime'].dt.year
fileData['month'] = fileData['datetime'].dt.month
fileData['weekday'] = fileData['datetime'].dt.day_name()
fileData['hour'] = fileData['datetime'].dt.hour

# %%
# drop datetime column
fileData.drop(["datetime"],axis=1, inplace=True)

# %%
fileData.dtypes
# Out:
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# year            int64
# month           int64
# weekday        object
# hour            int64
# dtype: object

# %% [markdown]
# ###### Observing having an object feature (weekday), will firstly detect if there is correlation between that object and target variable to convert it to numeric. If not, get rid of it

# %%
# Plotting count according to weekday
plt.title("Plotting count according to weekday")
sns.barplot(x = 'weekday', y = "count", data = fileData)
plt.show()

# %% [markdown]
# ##### Uniform distribution throughout the week, then will drop it

# %%
# drop weekday feature
fileData.drop('weekday', axis=1, inplace=True)

# %% [markdown]
# ### plot count distribution according to categorical fetures (season, holiday, workingday and weather)

# %%
# Plot 4 plots side by side in one row 
fig, ax = plt.subplots(1,4, figsize=(17,4))

#title
fig.suptitle("Count distribution by categorical fetures", fontsize=14)
 
sns.barplot(x = "season", y = "count", data = fileData, ax = ax[0])
sns.barplot(x = "holiday", y = "count", data = fileData, ax = ax[1])
sns.barplot(x = "workingday", y = "count", data = fileData, ax = ax[2])
sns.barplot(x = "weather", y = "count", data = fileData, ax = ax[3])

fig.show()
# Out:
# <ipython-input-17-f6d4bdba43db>:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ##### The biggest amount of renting bikes is in sunny and clear weather
# ##### Count is almost consistent in general throughout the holiday & workingday. To make sure, will detect their correlation with (count) to decide to drop them or not
# ##### From Season distribution observing the least amount of renting bikes is in Spring

# %%
# distrbuiton of weather and its frequency
sns.countplot(x='weather', 
              data=fileData)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
print(fileData['weather'].value_counts())
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %% [markdown]
# ##### Observing from the 2 cells above the biggest frequency is in sunny and clear weather
# ##### The more rainy, cloudy and cold the weather is, the less the frequency become

# %%
#  plotting the pie chart for (workingday) 
workingdayFrequency = fileData['workingday'].value_counts()
plt.pie(workingdayFrequency, 
        labels = fileData['workingday'].unique(),
        autopct = '%.1f%%'
       )

plt.title("Piechart Season")
plt.legend(title="Categories ",
          bbox_to_anchor=(0.5, 0, 1, 1)
          )
plt.show()

# %%
data_corr = fileData.corr()
plt.figure(figsize=(14,7))
sns.heatmap(data_corr, annot=True, linewidths=0.05)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### There  is almost no correlation between (count) and categorical varibles (season, holiday, workingday, weather), drop them
# ##### As well low correlation between (count) and month, year and windspeed. Drop them
# ##### observing that temp & atemp are highly correlated and affecting (count) feature in same proportion, as their function almost the same. Need to drop one of them.

# %% [markdown]
# ### Drop low correlated features with the target variable

# %%
featuresToDrop = ['atemp','season','holiday','workingday',
                  'weather', 'month', 'year', 'windspeed'
                 ]
fileData.drop(featuresToDrop, axis=1, inplace=True)

# %%
#Detect distribution and skewness for features
fileData.hist(figsize=(15,15), 
              bins=100
             )
# Out:
# array([[<AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'humidity'}>],
#        [<AxesSubplot:title={'center':'casual'}>,
#         <AxesSubplot:title={'center':'registered'}>],
#        [<AxesSubplot:title={'center':'count'}>,
#         <AxesSubplot:title={'center':'hour'}>]], dtype=object)

# %% [markdown]
# ##### Observe casual, registered and count features are right skewed, meaning having outliers needed to be handled
# ##### Identify outliers with the help of boxplot, to observe data points outside the range of the data

# %% [markdown]
# ### Boxplot to observe outliers

# %%
# Plot 3 plots on one row side by side
fig, ax = plt.subplots(1,3, figsize=(18,7))

# casual, registered and count customers box plots
fileData.boxplot("casual", ax=ax[0])
fileData.boxplot("registered", ax=ax[1])
fileData.boxplot("count", ax=ax[2])
fig.show()
# Out:
# <ipython-input-24-2c4a90307206>:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fileData['count'].corr(fileData['registered'])
# Out:
# 0.9709481058098282

# %%
# Give us the (density)
plt.figure(figsize=(7,4)) # changing its size
sns.distplot(fileData.casual)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print((fileData['casual'] > fileData['casual'].quantile(.97)).sum())
print((fileData['casual'] < fileData['casual'].quantile(.05)).sum())

print((fileData['registered'] > fileData['registered'].quantile(.97)).sum())
print((fileData['registered'] < fileData['registered'].quantile(.05)).sum())

print((fileData['count'] > fileData['count'].quantile(.97)).sum())
print((fileData['count'] < fileData['count'].quantile(.05)).sum())
# Out:
# 322
# 0
# 327
# 495
# 326
# 530

# %% [markdown]
# ### Detect outliers between count & casual from scatter plot

# %%
plt.figure(figsize = (8,4))
sns.scatterplot(x = fileData['count'], y = fileData['casual'])
plt.xlabel('count')
plt.ylabel('casual')
plt.show()

# %% [markdown]
# ### Detect outliers between count & registered from scatter plot

# %%
plt.figure(figsize = (8,4))
sns.scatterplot(x = fileData['count'], y = fileData['registered'])
plt.xlabel('count')
plt.ylabel('registered')
plt.show()

# %% [markdown]
# #### Almost fitted

# %% [markdown]
# # Handle outliers

# %%
def handle_outliers(feature):
    upper_lim = fileData[feature].quantile(.95)
    lower_lim = fileData[feature].quantile(.05)

    return fileData[(fileData[feature] < upper_lim) & (fileData[feature] > lower_lim)]
    
fileData = handle_outliers('casual')
fileData = handle_outliers('count')

# %%
fileData.shape
# Out:
# (8402, 6)
